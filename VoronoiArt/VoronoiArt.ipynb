# %%
using Pkg
Pkg.activate("../GenerativeArt")
# Out:
#   Activating project at `~/Spare Time/Generative_Art/GenerativeArt`

# %%
using ImageIO, Images, FileIO, Makie, ImageFiltering

# %%
path = "Snake.jpg"
image = load(path)
# Out:
# ┌ Info: Precompiling JpegTurbo [b835a17e-a41a-41e7-81f0-2f016b05efe0]
# └ @ Base loading.jl:1662
# ┌ Info: Precompiling PNGFiles [f57f5aa1-a3ce-4bc8-8ab9-96f992907883]
# └ @ Base loading.jl:1662
# 1200×1920 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.067,0.098,0.047)  …  RGB{N0f8}(0.008,0.008,0.008)
#  RGB{N0f8}(0.071,0.102,0.051)     RGB{N0f8}(0.004,0.004,0.004)
#  RGB{N0f8}(0.067,0.09,0.043)      RGB{N0f8}(0.004,0.004,0.004)
#  RGB{N0f8}(0.067,0.09,0.051)      RGB{N0f8}(0.004,0.004,0.004)
#  RGB{N0f8}(0.078,0.102,0.063)     RGB{N0f8}(0.004,0.004,0.004)
#  RGB{N0f8}(0.078,0.102,0.063)  …  RGB{N0f8}(0.004,0.004,0.004)
#  RGB{N0f8}(0.071,0.094,0.055)     RGB{N0f8}(0.004,0.004,0.004)
#  RGB{N0f8}(0.071,0.094,0.055)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.071,0.09,0.063)      RGB{N0f8}(0.0,0.0,0.008)
#  RGB{N0f8}(0.075,0.094,0.067)     RGB{N0f8}(0.0,0.0,0.008)
#  RGB{N0f8}(0.063,0.082,0.055)  …  RGB{N0f8}(0.0,0.0,0.008)
# ...

# %%
edges = ImageFiltering.imgradients(image, KernelFactors.ando5)[2]
# Out:
# 1200×1920 Array{RGB{Float64},2} with eltype RGB{Float64}:
#  RGB{Float64}(0.000287317,-0.00049772,0.0029709)      …  RGB{Float64}(0.00143285,0.00143285,0.00143285)
#  RGB{Float64}(5.49604e-5,-0.000324378,0.00286924)        RGB{Float64}(0.00135593,0.00135593,0.00135593)
#  RGB{Float64}(0.000135298,0.000379224,0.00275869)        RGB{Float64}(0.00141774,0.00141774,0.00141774)
#  RGB{Float64}(0.000587504,0.00107012,0.00246031)         RGB{Float64}(0.00140264,0.00140264,0.00140264)
#  RGB{Float64}(0.000878243,0.00131608,0.00222614)         RGB{Float64}(0.00123563,0.00123563,0.00123563)
#  RGB{Float64}(0.00101012,0.00139299,0.00235802)       …  RGB{Float64}(0.00109057,0.00109057,0.00109057)
#  RGB{Float64}(0.00106036,0.00119042,0.00283835)          RGB{Float64}(0.00072784,0.00072784,0.000758051)
#  RGB{Float64}(0.000672879,0.000494811,0.00254113)        RGB{Float64}(-0.000225508,-0.000225508,-1.51058e-5)
# ...

# %%
edges[1],edges[2]
# Out:
# (RGB{Float64}[RGB{Float64}(0.0010452541345797668,0.00026021703185483337,0.0006527355832173025) RGB{Float64}(0.0005572921603223309,0.0001930593345016499,0.00037517574741199194) … RGB{Float64}(-0.001205530123243318,-0.001205530123243318,-0.001205530123243318) RGB{Float64}(-0.00149819571675076,-0.00149819571675076,-0.00149819571675076); RGB{Float64}(1.0386014681920195e-5,-0.0028609788488711966,-0.0007826855431622366) RGB{Float64}(-0.0005730193824704849,-0.0020034359374220406,-0.0007846113330247151) … RGB{Float64}(-0.001483089959048628,-0.001483089959048628,-0.001483089959048628) RGB{Float64}(-0.001538050365171765,-0.001538050365171765,-0.001538050365171765); … ; RGB{Float64}(-0.001895434011133437,-0.0018954340111334337,-0.002660955821196183) RGB{Float64}(-0.0021661446670797413,-0.0021661446670797387,-0.00349136015280523) … RGB{Float64}(-0.0007678088120888051,-0.0007678088120888089,-0.0007678088120888074) RGB{Float64}(0.0006475019851606166,0.0006475019851606127,0.0006475019851606133); RG
# ...
